# %%
while True:
    n = input()
    if n == '0':
        break

    # 펠린드롬수면
    if n == n[::-1]:
        print('yes')

    # 펠린드롬수가 아니면
    else:
        print('no')
# Out:
# 121
# yes
# 1231
# no
# 12421
# yes
# 0

# %% [markdown]
# ![image.png](attachment:image.png)
