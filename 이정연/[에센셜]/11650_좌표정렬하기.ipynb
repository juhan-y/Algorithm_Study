# %%
n = int(input())
array = []
for _ in range(n):
    array.append(list(map(int, input().split())))
# Out:
# 5
# 3 4
# 1 1
# 1 -1
# 2 2
# 3 3

# %%
array_sorted = sorted(array, key=lambda x: (x[0], x[1]))

for i in array_sorted:
    print(i[0], i[1])
# Out:
# 1 -1
# 1 1
# 2 2
# 3 3
# 3 4
