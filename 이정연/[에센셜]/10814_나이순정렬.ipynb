# %%
n = int(input())
array = []

for _ in range(n):
    array.append(input().split())
    
members = sorted(array, key = lambda x: int(x[0]))

for i in members:
    print(i[0], i[1])
# Out:
# 3
# 21 Junkyu
# 21 Dohyun
# 20 Sunyoung
# 20 Sunyoung
# 21 Junkyu
# 21 Dohyun
